# %%
# Shortcut for running a cell - shift/enter
# Press d twice to delete a cell
import csv
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
output_notebook() # Load Bokeh into Jupyter Notebook
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7d529cf7-5315-46c9-aea7-132382b3a0b1">Loading BokehJS ...</span>
#     </div>

# %%
# Low-level
p = figure(plot_width=400, plot_height=400)

p.vbar(x=[1, 2, 3], width=0.5, bottom=0,
       top=[1.2, 2.5, 3.7], color="firebrick")
# Out:
# GlyphRenderer(id='7bfbf52a-6cb3-434a-957c-c150830ec53c', ...)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5ebe5a62-fce8-4287-8751-65a9a8e31532"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5ebe5a62-fce8-4287-8751-65a9a8e31532");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ebe5a62-fce8-4287-8751-65a9a8e31532");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ebe5a62-fce8-4287-8751-65a9a8e31532' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"29c096b8-c96d-4f10-8f68-72791a882ccd":{"roots":{"references":[{"attributes":{"plot":{"id":"5c12f917-7829-428b-8c67-eaf8d9a129c1","subtype":"Figure","type":"Plot"}},"id":"b8c37022-c1cb-4154-b916-2cbd2075c7cc","type":"ResetTool"},{"attributes":{"plot":{"id":"5c12f917-7829-428b-8c67-eaf8d9a129c1","subtype":"Figure","type":"Plot"}},"id":"07ac58e4-b19d-4cf7-b154-5208c7b6e0b4","type":"HelpTool"},{"attributes":{},"id":"00c8d213-5576-4b85-abea-7511415ab47f","type":"LinearScale"},{"attributes":{"plot":null,"text":""},"id":"355acede-99b2-4931-83ed-ebc468cdc9f0","type":"Title"},{"attributes":{"callback":null},"id":"fd908874-a752-43aa-b00e-c959af543afa","type":"DataRange1d"},{"attributes":{"below":[{"id":"1626e26f-7d86-4f69-a1ba-446078bbf60f","type":"LinearAxis"}],"left":[{"id":"d0a06bc2-9c9b-4dcf-80e7-447317550e1e","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"1626e26f-7d86-4f69-a1ba-446078bbf60f","type":"LinearAxis"},{"id":"5b3f8773-9966-4a66-9be3-a788935f4c7b","type":"Grid"},{"id":"d0a06bc2-9c9b-4dcf-80e7-447317550e1e","type":"LinearAxis"},{"id":"a7377f60-d4df-4048-ae2f-2660e486ecab","type":"Grid"},{"id":"d527b235-94d3-43c2-b812-0dd9400841d7","type":"BoxAnnotation"},{"id":"7bfbf52a-6cb3-434a-957c-c150830ec53c","type":"GlyphRenderer"}],"title":{"id":"355acede-99b2-4931-83ed-ebc468cdc9f0","type":"Title"},"tool_events":{"id":"2e74d2f8-79d5-4d8e-abfc-b5dff72f8bbb","type":"ToolEvents"},"toolbar":{"id":"4dcabb67-c050-4ff0-b946-e8cf1d3f0758","type":"Toolbar"},"x_range":{"id":"fd908874-a752-43aa-b00e-c959af543afa","type":"DataRange1d"},"x_scale":{"id":"00c8d213-5576-4b85-abea-7511415ab47f","type":"LinearScale"},"y_range":{"id":"c9f21697-31b8-4318-bc77-0f15def13bc2","type":"DataRange1d"},"y_scale":{"id":"b0633599-e47d-4ad3-a7a1-c36c65d91570","type":"LinearScale"}},"id":"5c12f917-7829-428b-8c67-eaf8d9a129c1","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[1.2,2.5,3.7],"x":[1,2,3]}},"id":"91b33701-0329-472b-8a59-9abf6056d77a","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"firebrick"},"line_color":{"value":"firebrick"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"bcf5fafd-7075-4d1a-8a8a-e72dba768260","type":"VBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"83bd90ff-be92-41dd-8aed-ad60ddad9512","type":"VBar"},{"attributes":{},"id":"2e74d2f8-79d5-4d8e-abfc-b5dff72f8bbb","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b89cf95f-18e7-4a40-84f7-7db5528c4058","type":"PanTool"},{"id":"6b42eed3-15c0-4449-861c-c12c36019c16","type":"WheelZoomTool"},{"id":"d6e9a8d8-12bf-4964-9584-b935d705cea7","type":"BoxZoomTool"},{"id":"5654e108-2ad4-4b96-a7a3-47a929892825","type":"SaveTool"},{"id":"b8c37022-c1cb-4154-b916-2cbd2075c7cc","type":"ResetTool"},{"id":"07ac58e4-b19d-4cf7-b154-5208c7b6e0b4","type":"HelpTool"}]},"id":"4dcabb67-c050-4ff0-b946-e8cf1d3f0758","type":"Toolbar"},{"attributes":{"callback":null},"id":"c9f21697-31b8-4318-bc77-0f15def13bc2","type":"DataRange1d"},{"attributes":{},"id":"b0633599-e47d-4ad3-a7a1-c36c65d91570","type":"LinearScale"},{"attributes":{},"id":"abdd6098-b8aa-46f4-beb7-c5b65b87c22a","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"abdd6098-b8aa-46f4-beb7-c5b65b87c22a","type":"BasicTickFormatter"},"plot":{"id":"5c12f917-7829-428b-8c67-eaf8d9a129c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"de8af5ca-f1f2-4fd3-be6f-eccc9a0cfe0a","type":"BasicTicker"}},"id":"1626e26f-7d86-4f69-a1ba-446078bbf60f","type":"LinearAxis"},{"attributes":{},"id":"de8af5ca-f1f2-4fd3-be6f-eccc9a0cfe0a","type":"BasicTicker"},{"attributes":{"plot":{"id":"5c12f917-7829-428b-8c67-eaf8d9a129c1","subtype":"Figure","type":"Plot"},"ticker":{"id": ...
